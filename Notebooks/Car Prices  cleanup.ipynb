# %% [markdown]
# # Precios de los Vehiculos
# por: `Julio Assmann`
#
#
# En este notebook realizaremos una limpieza del notebook, además de modificar ciertas columnas para poder tratarlas, como lo son la columnas condition y saledate

# %%
#librerias cargadas para todo el notebook
import pandas as pd
from datetime import datetime
import re

# %%
#origen del archivo
csv_path='D:\Julio Assmann\Descargas\ProyectoFinal_Python\Data Sets\Data Original\car_prices.csv'
df= pd.read_csv(csv_path)

df.head(10)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\J'
# <>:2: SyntaxWarning: invalid escape sequence '\J'
# C:\Users\fpsju\AppData\Local\Temp\ipykernel_11816\4208965657.py:2: SyntaxWarning: invalid escape sequence '\J'
#   csv_path='D:\Julio Assmann\Descargas\ProyectoFinal_Python\Data Sets\Data Original\car_prices.csv'
#    year       make                model                       trim  \
# 0  2015        Kia              Sorento                         LX
# 1  2015        Kia              Sorento                         LX
# 2  2014        BMW             3 Series                 328i SULEV
# 3  2015      Volvo                  S60                         T5
# 4  2014        BMW  6 Series Gran Coupe                       650i
# 5  2015     Nissan               Altima                      2.5 S
# 6  2014        BMW                   M5                       Base
# 7  2014  Chevrolet                Cruze                        1LT
# ...

# %% [markdown]
# ## Descripción de Columnas
#
# -   `year` :(int64) Columna que muestra el año de producción del auto.
# -   `make` : (object) Columna que muestra fábrica del auto.
# -   `model`: (object) Columna que muestra modelo del auto.
# -   `trim` : (object) Columna que muestra  versión del modelo.
# -   `body` : (object) Columna que muestra tipo del vehiculo.
# -   `transmision`: (object) Columna que muestra tipo de transmisión.
# -   `vin`:  (object) Columna que muestra ID unica del vehiculo (vehicule identification number).
# -   `state`: (object) Columna que muestra estado donde se vendió el auto.
# -   `condition`: (float64) Columna que muestra nota de calidad del estado del vehuculo (-1 a 5+).
# -   `odometer`: (float64) Columna que muestra millaje del vehiculo.
# -   `color`: (object) Columna que muestra color del vehiculo.
# -   `interior` : (object) Columna que muestra color del interior del vehiculo.
# -   `seller` : (object) Columna que muestra nombre del vendedor del vehivulo.
# -   `mmr` : (object) Columna que muestra el  "Manheim Market Report"  valor establecido para el vehiculo.
# -   `sellingprice` : (object) Columna que muestra el valor de venta del vehiculo.
# -   `saledate`: (object) Columna que muestra la fecha de venta del vehiculo.

# %%
#revision de nulos
null_counts = df.isnull().sum()
null_counts
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
print(df.dtypes)
# Out:
# year              int64
# make             object
# model            object
# trim             object
# body             object
# transmission     object
# vin              object
# state            object
# condition       float64
# odometer        float64
# color            object
# interior         object
# seller           object
# mmr             float64
# sellingprice    float64
# saledate         object
# dtype: object

# %%
# Corregir columna condition ( valores entre 1 a 5)
def correct_condition(value):
    if value > 5:
        value = value / 10  
    return value

df['condition'] = df['condition'].apply(correct_condition)

condition_corrected = df['condition'].between(1, 5).all()
print("Columna 'Condition' corregida:", condition_corrected)

# revisar los tipos de resultados en esta columna, ya que los NAN los pasaremos a 0
df['condition'] = df['condition'].fillna(0)

unique_values = df['condition'].unique()
print("\nUnique values in the 'condition' column (after filling NaNs with 0):", unique_values)
value_counts = df['condition'].value_counts()
# Out:
# Columna 'Condition' corregida: False
#
# Unique values in the 'condition' column (after filling NaNs with 0): [5.  4.5 4.1 4.3 1.  3.4 2.  4.2 3.  4.8 0.  4.9 1.7 1.9 2.9 3.8 4.4 4.7
#  3.2 4.  2.5 3.7 3.9 3.1 2.8 4.6 3.6 3.5 2.6 2.1 2.2 2.7 2.4 3.3 2.3 1.5
#  1.6 1.8 1.2 1.4 1.1 1.3]

# %%
#eliminar filas vacias relacionadas al make, ya que  pueden ser autos custom sin marca o errores de la tabla y no los necesitamos para la revisión
df = df.dropna(subset=['make'])
null_counts_after_dropping_make = df.isnull().sum()

#remplazar los NAN por "Not Specified"
df = df.fillna("Not Specified")
null_counts_after_filling = df.isnull().sum()
print("\nNumber of null values in each column after filling NaNs with 'Not Specified':")
print(null_counts_after_filling)

# ver data set
df.head(10)
# Out:
# Number of null values in each column after filling NaNs with 'Not Specified':
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64
#    year       make                model                       trim  \
# 0  2015        Kia              Sorento                         LX
# 1  2015        Kia              Sorento                         LX
# 2  2014        BMW             3 Series                 328i SULEV
# 3  2015      Volvo                  S60                         T5
# 4  2014        BMW  6 Series Gran Coupe                       650i
# 5  2015     Nissan               Altima                      2.5 S
# 6  2014        BMW                   M5                       Base
# ...

# %%
#modificar la columna saledate
def format_saledate(date_str):
    match = re.match(r'(.*\d{4} \d{2}:\d{2}:\d{2})', date_str)
    if match:
        clean_date_str = match.group(1)
    else:
        # fecha generica para identificar en futuro
        clean_date_str = 'Fri Jul 16 1963 23:59:00'
    
    try:
        dt = datetime.strptime(clean_date_str, '%a %b %d %Y %H:%M:%S')
    except ValueError:
        dt = datetime.strptime('Fri Jul 16 1963 23:59:00', '%a %b %d %Y %H:%M:%S')
    
    return dt

df['formatted_date'] = df['saledate'].apply(format_saledate)

#generar columna para control de ventas por año
df['saleyear'] = df['formatted_date'].dt.year


print(df.head(10))
# Out:
#    year       make                model                       trim  \
# 0  2015        Kia              Sorento                         LX
# 1  2015        Kia              Sorento                         LX
# 2  2014        BMW             3 Series                 328i SULEV
# 3  2015      Volvo                  S60                         T5
# 4  2014        BMW  6 Series Gran Coupe                       650i
# 5  2015     Nissan               Altima                      2.5 S
# 6  2014        BMW                   M5                       Base
# 7  2014  Chevrolet                Cruze                        1LT
# 8  2014       Audi                   A4  2.0T Premium Plus quattro
# 9  2014  Chevrolet               Camaro                         LT
#
#           body transmission                vin state  condition odometer  \
# 0          SUV    automatic  5xyktca69fg566472    ca        5.0  16639.0
# 1          SUV    automatic  5xyktca69fg561319    ca        5.0   9393.0
# ...

# %%
file_path = r'D:\Julio Assmann\Descargas\ProyectoFinal_Python\Data Sets\Data  Limpia\car_prices.csv'

# Save the DataFrame to a CSV file at the specified location
df.to_csv(file_path, index=False)

print(f"DataFrame successfully saved to {file_path}")
# Out:
# DataFrame successfully saved to D:\Julio Assmann\Descargas\ProyectoFinal_Python\Data Sets\Data  Limpia\car_prices.csv
